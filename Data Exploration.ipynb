# %% [markdown]
# # Data Exploration

# %%
#Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Explore indexInfo file

# %%
indexInfo = pd.read_csv("Data_Exploration/indexInfo.csv")
indexInfo
# Out:
#            Region                          Exchange      Index Currency
# 0   United States           New York Stock Exchange        NYA      USD
# 1   United States                            NASDAQ       IXIC      USD
# 2       Hong Kong          Hong Kong Stock Exchange        HSI      HKD
# 3           China           Shanghai Stock Exchange  000001.SS      CNY
# 4           Japan              Tokyo Stock Exchange       N225      JPY
# 5          Europe                          Euronext       N100      EUR
# 6           China           Shenzhen Stock Exchange  399001.SZ      CNY
# 7          Canada            Toronto Stock Exchange     GSPTSE      CAD
# 8           India  National Stock Exchange of India       NSEI      INR
# 9         Germany          Frankfurt Stock Exchange      GDAXI      EUR
# 10          Korea                    Korea Exchange       KS11      KRW
# 11    Switzerland                SIX Swiss Exchange       SSMI      CHF
# ...

# %% [markdown]
# Since we want to analyze New York Stock Exchange data, we will filter by NYA

# %% [markdown]
# ## Explore indexProcessed file

# %%
indexProcessed = pd.read_csv("Data_Exploration/indexProcessed.csv")
indexProcessed
# Out:
#           Index        Date          Open          High           Low  \
# 0           HSI  1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI  1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI  1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI  1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI  1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...         ...           ...           ...           ...
# 104219  J203.JO  2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO  2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO  2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO  2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO  2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049     0.0   333.879006
# ...

# %%
indexProcessed.describe()
# Out:
#                 Open           High            Low          Close  \
# count  104224.000000  104224.000000  104224.000000  104224.000000
# mean     8015.353334    8063.324234    7962.581120    8014.366642
# std      9140.563404    9196.575802    9082.767802    9140.609758
# min        54.869999      54.869999      54.869999      54.869999
# 25%      2046.887756    2057.213990    2037.185943    2047.506470
# 50%      5772.140137    5812.764892    5725.199951    5773.710205
# 75%     10487.377445   10552.179690   10416.092287   10488.622560
# max     68775.062500   69403.750000   68516.992190   68775.062500
#
#            Adj Close        Volume       CloseUSD
# count  104224.000000  1.042240e+05  104224.000000
# mean     8014.161269  1.347646e+09    3046.729177
# std      9140.720456  4.427662e+09    3747.865623
# min        54.869999  0.000000e+00      10.204900
# 25%      2047.358490  0.000000e+00     320.460898
# 50%      5773.710205  9.529000e+05    1371.598486
# ...

# %%
indexProcessed.dtypes
# Out:
# Index         object
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# CloseUSD     float64
# dtype: object

# %%
NYA = indexProcessed[indexProcessed.Index == "NYA"]
NYA
# Out:
#       Index        Date          Open          High           Low  \
# 8492    NYA  1965-12-31    528.690002    528.690002    528.690002
# 8493    NYA  1966-01-03    527.210022    527.210022    527.210022
# 8494    NYA  1966-01-04    527.840027    527.840027    527.840027
# 8495    NYA  1966-01-05    531.119995    531.119995    531.119995
# 8496    NYA  1966-01-06    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 22434   NYA  2021-05-24  16375.000000  16508.519530  16375.000000
# 22435   NYA  2021-05-25  16464.689450  16525.810550  16375.150390
# 22436   NYA  2021-05-26  16390.189450  16466.339840  16388.320310
# 22437   NYA  2021-05-27  16451.960940  16546.359380  16451.960940
# 22438   NYA  2021-05-28  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume      CloseUSD
# 8492     528.690002    528.690002  0.000000e+00    528.690002
# ...

# %%
NYA.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13947.000000  13947.000000  13947.000000  13947.000000  13947.000000
# mean    4451.778151   4468.236552   4433.695014   4452.174711   4452.174711
# std     4074.953735   4095.166918   4052.801658   4075.459366   4075.459366
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      654.940002    654.940002    654.940002    654.940002    654.940002
# 50%     2631.800049   2631.800049   2631.800049   2631.800049   2631.800049
# 75%     7339.489990   7375.719971   7276.889893   7337.935059   7337.935059
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume      CloseUSD
# count  1.394700e+04  13947.000000
# mean   1.215565e+09   4452.174711
# std    1.834155e+09   4075.459366
# min    0.000000e+00    347.769989
# 25%    0.000000e+00    654.940002
# 50%    0.000000e+00   2631.800049
# 75%    2.681975e+09   7337.935059
# ...

# %%
NYA.isna().sum()
# Out:
# Index        0
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# CloseUSD     0
# dtype: int64

# %% [markdown]
# ## Explore CPI file

# %%
CPI = pd.read_csv("Data_Exploration/CPI.csv")
CPI
# Out:
#          LOCATION INDICATOR       SUBJECT  MEASURE FREQUENCY     TIME  \
# 0             AUS       CPI          ENRG   AGRWTH         A     1972
# 1             AUS       CPI          ENRG   AGRWTH         A     1973
# 2             AUS       CPI          ENRG   AGRWTH         A     1974
# 3             AUS       CPI          ENRG   AGRWTH         A     1975
# 4             AUS       CPI          ENRG   AGRWTH         A     1976
# ...           ...       ...           ...      ...       ...      ...
# 285412  EU27_2020       CPI  TOT_FOODENRG  IDX2015         M  2021-05
# 285413  EU27_2020       CPI  TOT_FOODENRG  IDX2015         M  2021-06
# 285414  EU27_2020       CPI  TOT_FOODENRG  IDX2015         M  2021-07
# 285415  EU27_2020       CPI  TOT_FOODENRG  IDX2015         M  2021-08
# 285416  EU27_2020       CPI  TOT_FOODENRG  IDX2015         M  2021-09
#
#              Value Flag Codes
# 0         4.910070        NaN
# 1         3.762801        NaN
# 2        13.173540        NaN
# ...

# %%
CPI.describe()
# Out:
#                Value
# count  285417.000000
# mean       35.652072
# std        77.194852
# min      -100.000000
# 25%         2.948022
# 50%        12.590480
# 75%        66.058690
# max      6821.312000

# %%
CPI.dtypes
# Out:
# LOCATION       object
# INDICATOR      object
# SUBJECT        object
# MEASURE        object
# FREQUENCY      object
# TIME           object
# Value         float64
# Flag Codes     object
# dtype: object

# %%
CPI.LOCATION.unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU',
#        'GRC', 'HUN', 'ISL', 'IRL', 'ITA', 'JPN', 'KOR', 'LUX', 'MEX',
#        'NLD', 'NZL', 'NOR', 'POL', 'PRT', 'SVK', 'ESP', 'SWE', 'CHE',
#        'TUR', 'GBR', 'USA', 'BRA', 'CHL', 'CHN', 'EST', 'IND', 'IDN',
#        'ISR', 'RUS', 'SVN', 'ZAF', 'OECD', 'OECDE', 'G-7', 'COL', 'LVA',
#        'SAU', 'EA19', 'ARG', 'LTU', 'CRI', 'G-20', 'EU27_2020'],
#       dtype=object)

# %%
CPI.SUBJECT.unique()
# Out:
# array(['ENRG', 'FOOD', 'TOT', 'TOT_FOODENRG'], dtype=object)

# %%
CPI.MEASURE.unique()
# Out:
# array(['AGRWTH', 'IDX2015'], dtype=object)

# %%
CPI.FREQUENCY.unique()
# Out:
# array(['A', 'Q', 'M'], dtype=object)

# %%
CPI.isna().sum()
# Out:
# LOCATION           0
# INDICATOR          0
# SUBJECT            0
# MEASURE            0
# FREQUENCY          0
# TIME               0
# Value              0
# Flag Codes    285366
# dtype: int64

# %% [markdown]
# ## Explore GDP file

# %%
GDP = pd.read_csv("Data_Exploration/GDP.csv")
GDP
# Out:
#            DATE      GDPC1
# 0    1947-01-01   2034.450
# 1    1947-04-01   2029.024
# 2    1947-07-01   2024.834
# 3    1947-10-01   2056.508
# 4    1948-01-01   2087.442
# ..          ...        ...
# 294  2020-07-01  18560.774
# 295  2020-10-01  18767.778
# 296  2021-01-01  19055.655
# 297  2021-04-01  19368.310
# 298  2021-07-01  19465.195
#
# [299 rows x 2 columns]

# %%
GDP.describe()
# Out:
#               GDPC1
# count    299.000000
# mean    8924.575816
# std     5319.684493
# min     2024.834000
# 25%     4256.256500
# 50%     7617.547000
# 75%    13584.427500
# max    19465.195000

# %%
GDP.dtypes
# Out:
# DATE      object
# GDPC1    float64
# dtype: object

# %%
GDP.DATE.unique()
# Out:
# array(['1947-01-01', '1947-04-01', '1947-07-01', '1947-10-01',
#        '1948-01-01', '1948-04-01', '1948-07-01', '1948-10-01',
#        '1949-01-01', '1949-04-01', '1949-07-01', '1949-10-01',
#        '1950-01-01', '1950-04-01', '1950-07-01', '1950-10-01',
#        '1951-01-01', '1951-04-01', '1951-07-01', '1951-10-01',
#        '1952-01-01', '1952-04-01', '1952-07-01', '1952-10-01',
#        '1953-01-01', '1953-04-01', '1953-07-01', '1953-10-01',
#        '1954-01-01', '1954-04-01', '1954-07-01', '1954-10-01',
#        '1955-01-01', '1955-04-01', '1955-07-01', '1955-10-01',
#        '1956-01-01', '1956-04-01', '1956-07-01', '1956-10-01',
#        '1957-01-01', '1957-04-01', '1957-07-01', '1957-10-01',
#        '1958-01-01', '1958-04-01', '1958-07-01', '1958-10-01',
#        '1959-01-01', '1959-04-01', '1959-07-01', '1959-10-01',
#        '1960-01-01', '1960-04-01', '1960-07-01', '1960-10-01',
#        '1961-01-01', '1961-04-01', '1961-07-01', '1961-10-01',
# ...

# %%
GDP.isna().sum()
# Out:
# DATE     0
# GDPC1    0
# dtype: int64

# %% [markdown]
# ## Explore Working Pop file

# %%
Pop = pd.read_csv("Data_Exploration/Working Pop.csv")
Pop
# Out:
#            DATE  LFWA64TTUSM647S
# 0    1977-01-01     1.352354e+08
# 1    1977-02-01     1.354273e+08
# 2    1977-03-01     1.356365e+08
# 3    1977-04-01     1.357819e+08
# 4    1977-05-01     1.361112e+08
# ..          ...              ...
# 532  2021-05-01     2.058753e+08
# 533  2021-06-01     2.054502e+08
# 534  2021-07-01     2.051790e+08
# 535  2021-08-01     2.050869e+08
# 536  2021-09-01     2.050531e+08
#
# [537 rows x 2 columns]

# %%
Pop.describe()
# Out:
#        LFWA64TTUSM647S
# count     5.370000e+02
# mean      1.760931e+08
# std       2.280506e+07
# min       1.352354e+08
# 25%       1.556179e+08
# 50%       1.750168e+08
# 75%       1.990869e+08
# max       2.073116e+08

# %%
Pop.dtypes
# Out:
# DATE                object
# LFWA64TTUSM647S    float64
# dtype: object

# %%
Pop.DATE.unique()
# Out:
# array(['1977-01-01', '1977-02-01', '1977-03-01', '1977-04-01',
#        '1977-05-01', '1977-06-01', '1977-07-01', '1977-08-01',
#        '1977-09-01', '1977-10-01', '1977-11-01', '1977-12-01',
#        '1978-01-01', '1978-02-01', '1978-03-01', '1978-04-01',
#        '1978-05-01', '1978-06-01', '1978-07-01', '1978-08-01',
#        '1978-09-01', '1978-10-01', '1978-11-01', '1978-12-01',
#        '1979-01-01', '1979-02-01', '1979-03-01', '1979-04-01',
#        '1979-05-01', '1979-06-01', '1979-07-01', '1979-08-01',
#        '1979-09-01', '1979-10-01', '1979-11-01', '1979-12-01',
#        '1980-01-01', '1980-02-01', '1980-03-01', '1980-04-01',
#        '1980-05-01', '1980-06-01', '1980-07-01', '1980-08-01',
#        '1980-09-01', '1980-10-01', '1980-11-01', '1980-12-01',
#        '1981-01-01', '1981-02-01', '1981-03-01', '1981-04-01',
#        '1981-05-01', '1981-06-01', '1981-07-01', '1981-08-01',
#        '1981-09-01', '1981-10-01', '1981-11-01', '1981-12-01',
# ...

# %%
Pop.isna().sum()
# Out:
# DATE               0
# LFWA64TTUSM647S    0
# dtype: int64
